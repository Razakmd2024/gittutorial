# %% [markdown]
# <a href="https://www.kaggle.com/code/razakmd/machine-learning-house-pricepredication?scriptVersionId=208607025" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <font color='red'> This is my second machine learning project in Kaggle Notebook.</font>
# ## Here , i am using boston housing dataset to predict price by using Linear Regression model by sklearn model
# ### Total 13 Independent features and 1 dependent variable(i.e.,Target)

# %% [markdown]
# # Boston Housing dataset : feature details
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft. Models
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise) boston-house-prices Code
# * NOX - nitric oxides concentration (parts per 10 million) Language Discussions
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres More
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per `$10,000`
# * PTRATIO - pupil-teacher ratio by town Your Work VIEWED
# * B-1000(Bk-0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in $1000's

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
data.shape
# Out:
# (506, 13)

# %%
target.shape
# Out:
# (506,)

# %%
feature_names =["crim","zn","indus","chas","nox","rm","age","dis","rad","tax","ptratio","b","lstat"]

# %%
boston_df =pd.DataFrame(data, columns = feature_names)

# %%
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    ptratio       b  lstat
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df['price']=target

# %%
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
#verify the summary of the dataframe
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    float64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# As per summary report,\
# total 506 samples and 14 columns (13 features + 1 target varibles)\
# all datatypes are float64\
# zero null values

# %% [markdown]
# # Check the statistical summery of the dataset like- count, mean, std, min value, 1st Quartile (25%), Median Value(50%),3rd Quartile(75%) and Max value

# %%
boston_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#check is there any null values
boston_df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# price      0
# dtype: int64

# %% [markdown]
# # Check the correlation between independent variables and target variable

# %%
boston_df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# # Visualize the Data Frame

# %%
# import supporting plotting libaries like matplotlib and seaborn to visualize 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting the heatmap
plt.figure(figsize=(9, 9))  # Set the figure size
sns.heatmap(boston_df.corr(), annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# verify the crim and price by using scatter plot
plt.scatter(x=boston_df['crim'], y=boston_df['price'])
plt.xlabel("Crim")
plt.ylabel("Price")
plt.title("correlation between 'crim' and 'price'")
plt.show()

# %%
# check the correlation zn and price by using scatter plot
plt.scatter(x=boston_df['zn'], y=boston_df['price'])
plt.xlabel("zn")
plt.ylabel("Price")
plt.title("correlation between 'zn' and 'price'")
plt.show()

# %%
sns.regplot(x='rm', y='price',data=boston_df)
# Out:
# <Axes: xlabel='rm', ylabel='price'>

# %%
sns.regplot(x='ptratio', y='price', data = boston_df)
# Out:
# <Axes: xlabel='ptratio', ylabel='price'>

# %% [markdown]
# # separate the independent and dependent variable to train the model

# %%
X = boston_df.drop(columns = 'price')
y = boston_df.loc[:, 'price']

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 506, dtype: float64

# %% [markdown]
# # import the sklearn packages like
# 1. train_test_split
# 2. StandardScaler
# 3. Linear Regression
# 4. mean_squared_error
# 5. r2_score
#
# to train the model and predict the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
# split the X,y variables by using train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25,random_state=42)

# %%
# check the shape of xtrain, xtest, ytrain, ytest
print("xtrain Shape:", xtrain.shape)
print("xtest Shape:", xtest.shape)
print("ytrain Shape:", ytrain.shape)
print("ytest Shape:", ytest.shape)
# Out:
# xtrain Shape: (379, 13)
# xtest Shape: (127, 13)
# ytrain Shape: (379,)
# ytest Shape: (127,)

# %%
xtrain.head()
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad    tax  \
# 182  0.09103   0.0   2.46   0.0  0.4880  7.155  92.2  2.7006  3.0  193.0
# 155  3.53501   0.0  19.58   1.0  0.8710  6.152  82.6  1.7455  5.0  403.0
# 280  0.03578  20.0   3.33   0.0  0.4429  7.820  64.5  4.6947  5.0  216.0
# 126  0.38735   0.0  25.65   0.0  0.5810  5.613  95.6  1.7572  2.0  188.0
# 329  0.06724   0.0   3.24   0.0  0.4600  6.333  17.2  5.2146  4.0  430.0
#
#      ptratio       b  lstat
# 182     17.8  394.12   4.82
# 155     14.7   88.01  15.02
# 280     14.9  387.31   3.76
# 126     19.1  359.29  27.26
# 329     16.9  375.21   7.34

# %%
# By using StandardScaler, standarize the features values 
scaler = StandardScaler()

# %%
xtrain  = scaler.fit_transform(xtrain)

# %%
xtrain
# Out:
# array([[-0.40679535, -0.50281197, -1.24707626, ..., -0.20515671,
#          0.40451209, -1.07775629],
#        [ 0.00799171, -0.50281197,  1.21828293, ..., -1.57625236,
#         -3.09803734,  0.35116456],
#        [-0.41344957,  0.36438137, -1.12179223, ..., -1.48779457,
#          0.32659121, -1.22625199],
#        ...,
#        [-0.41595107,  2.96596138, -1.31187834, ..., -0.55898784,
#          0.36812613, -0.91385066],
#        [ 0.92638065, -0.50281197,  1.00515608, ...,  0.8563367 ,
#         -2.84814129,  1.50690937],
#        [-0.39020739, -0.50281197, -0.36864804, ...,  1.16593894,
#         -3.29495634, -0.26383177]])

# %%
#transform the xtest value using scaler.transform function 
xtest = scaler.transform(xtest)

# %%
xtest
# Out:
# array([[-0.40670502, -0.50281197, -1.0181089 , ..., -0.73590341,
#          0.42030222, -0.48657531],
#        [-0.41096131,  1.23157471, -0.67825799, ..., -0.29361449,
#          0.4363212 , -1.25847275],
#        [-0.40502371, -0.50281197,  2.39336067, ...,  0.81210781,
#          0.35862916,  0.77843992],
#        ...,
#        [-0.40071683, -0.50281197, -0.60625567, ..., -0.16092782,
#          0.28150923, -0.93906691],
#        [-0.37546815, -0.50281197, -0.5385735 , ...,  0.59096335,
#          0.4363212 , -0.67429629],
#        [-0.41550665,  3.18275972, -1.00370844, ..., -0.16092782,
#          0.38517489, -0.86201726]])

# %% [markdown]
# # Train the model by using linear regression model

# %%
# create model instance 
lr_model = LinearRegression()

# %%
#fit the model
lr_model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
#check the coefficent & intercept the trainined model 
lr_model.coef_
# Out:
# array([-1.06546379,  0.68154987,  0.33928836,  0.73726309, -1.93178062,
#         3.14172655, -0.25586276, -2.95561026,  2.21416067, -1.65127265,
#        -2.08714915,  1.15235744, -3.69504236])

# %%
#check the intercept of the model
lr_model.intercept_
# Out:
# 22.90791556728232

# %%
#predict the model by using test dataset
y_pred = lr_model.predict(xtest)

# %%
#compate the ytest & ypred values 
pd.DataFrame(np.c_[ytest,y_pred], columns = ['Actual_Value',"Predicated_value"])
# Out:
#      Actual_Value  Predicated_value
# 0            23.6         28.838854
# 1            32.4         36.007833
# 2            13.6         15.083248
# 3            22.8         25.230909
# 4            16.1         18.878641
# ..            ...               ...
# 122           8.8          3.284209
# 123          19.2         23.798796
# 124          25.3         25.733299
# 125          20.4         23.048156
# 126          23.1         24.730468
#
# [127 rows x 2 columns]

# %%
plt.scatter(ytest,y_pred)

# %%
#check the residual error
residual  = ytest-y_pred

# %%
#plot the residual error
sns.displot(x=residual, kind='kde')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.scatter(y_pred, residual)

# %%
#check the accuracy of the predication value
r2_score(ytest, y_pred)
# Out:
# 0.6844267283527132

# %%
#check the mean_squared_error
from sklearn.metrics import mean_squared_error
mean_squared_error(ytest, y_pred)
# Out:
# 22.098694827097983

# %%
#check the root mean squared error
np.sqrt(mean_squared_error(ytest,y_pred))
# Out:
# 4.700924890603761
